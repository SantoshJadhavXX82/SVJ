# %% [markdown]
# <a href="https://colab.research.google.com/github/SantoshJadhavXX82/SVJ/blob/main/Stock_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf

# %%
nifty50_data = yf.Ticker('RELIANCE.BO')

# %%
nifty50_data = nifty50_data.history(period='max')

# %%
nifty50_data
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2000-01-04 00:00:00+05:30    35.767719    35.767719    35.767719    35.767719
# 2000-01-05 00:00:00+05:30    36.180073    36.180073    36.180073    36.180073
# 2000-01-12 00:00:00+05:30    38.707344    38.707344    38.707344    38.707344
# 2000-02-07 00:00:00+05:30    46.176128    46.176128    46.176128    46.176128
# 2000-02-14 00:00:00+05:30    47.885376    47.885376    47.885376    47.885376
# ...                                ...          ...          ...          ...
# 2023-12-22 00:00:00+05:30  2562.199951  2580.550049  2548.000000  2564.699951
# 2023-12-26 00:00:00+05:30  2570.000000  2592.899902  2563.000000  2577.500000
# 2023-12-27 00:00:00+05:30  2578.500000  2599.350098  2572.250000  2586.350098
# 2023-12-28 00:00:00+05:30  2587.000000  2611.350098  2587.000000  2605.800049
# 2023-12-29 00:00:00+05:30  2608.050049  2614.800049  2579.149902  2584.850098
#
#                            Volume  Dividends  Stock Splits
# Date
# 2000-01-04 00:00:00+05:30    6400        0.0           0.0
# 2000-01-05 00:00:00+05:30  418568        0.0           0.0
# 2000-01-12 00:00:00+05:30    4200        0.0           0.0
# 2000-02-07 00:00:00+05:30    8000        0.0           0.0
# 2000-02-14 00:00:00+05:30    2000        0.0           0.0
# ...                           ...        ...           ...
# 2023-12-22 00:00:00+05:30  524558        0.0           0.0
# 2023-12-26 00:00:00+05:30   90284        0.0           0.0
# 2023-12-27 00:00:00+05:30  103806        0.0           0.0
# 2023-12-28 00:00:00+05:30  183810        0.0           0.0
# 2023-12-29 00:00:00+05:30  848448        0.0           0.0
#
# [5771 rows x 7 columns]

# %%
nifty50_data.index
# Out:
# DatetimeIndex(['2000-01-04 00:00:00+05:30', '2000-01-05 00:00:00+05:30',
#                '2000-01-12 00:00:00+05:30', '2000-02-07 00:00:00+05:30',
#                '2000-02-14 00:00:00+05:30', '2000-03-30 00:00:00+05:30',
#                '2000-03-31 00:00:00+05:30', '2000-04-05 00:00:00+05:30',
#                '2000-04-12 00:00:00+05:30', '2000-04-26 00:00:00+05:30',
#                ...
#                '2023-12-15 00:00:00+05:30', '2023-12-18 00:00:00+05:30',
#                '2023-12-19 00:00:00+05:30', '2023-12-20 00:00:00+05:30',
#                '2023-12-21 00:00:00+05:30', '2023-12-22 00:00:00+05:30',
#                '2023-12-26 00:00:00+05:30', '2023-12-27 00:00:00+05:30',
#                '2023-12-28 00:00:00+05:30', '2023-12-29 00:00:00+05:30'],
#               dtype='datetime64[ns, Asia/Kolkata]', name='Date', length=5771, freq=None)

# %%
nifty50_data.plot.line(y='Close', use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
del nifty50_data['Dividends']
del nifty50_data['Stock Splits']

# %%
nifty50_data['Tomorrow'] = nifty50_data['Close'].shift(-1)
nifty50_data
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2000-01-04 00:00:00+05:30    35.767719    35.767719    35.767719    35.767719
# 2000-01-05 00:00:00+05:30    36.180073    36.180073    36.180073    36.180073
# 2000-01-12 00:00:00+05:30    38.707344    38.707344    38.707344    38.707344
# 2000-02-07 00:00:00+05:30    46.176128    46.176128    46.176128    46.176128
# 2000-02-14 00:00:00+05:30    47.885376    47.885376    47.885376    47.885376
# ...                                ...          ...          ...          ...
# 2023-12-22 00:00:00+05:30  2562.199951  2580.550049  2548.000000  2564.699951
# 2023-12-26 00:00:00+05:30  2570.000000  2592.899902  2563.000000  2577.500000
# 2023-12-27 00:00:00+05:30  2578.500000  2599.350098  2572.250000  2586.350098
# 2023-12-28 00:00:00+05:30  2587.000000  2611.350098  2587.000000  2605.800049
# 2023-12-29 00:00:00+05:30  2608.050049  2614.800049  2579.149902  2584.850098
#
#                            Volume     Tomorrow
# Date
# 2000-01-04 00:00:00+05:30    6400    36.180073
# 2000-01-05 00:00:00+05:30  418568    38.707344
# 2000-01-12 00:00:00+05:30    4200    46.176128
# 2000-02-07 00:00:00+05:30    8000    47.885376
# 2000-02-14 00:00:00+05:30    2000    38.694046
# ...                           ...          ...
# 2023-12-22 00:00:00+05:30  524558  2577.500000
# 2023-12-26 00:00:00+05:30   90284  2586.350098
# 2023-12-27 00:00:00+05:30  103806  2605.800049
# 2023-12-28 00:00:00+05:30  183810  2584.850098
# 2023-12-29 00:00:00+05:30  848448          NaN
#
# [5771 rows x 6 columns]

# %%
nifty50_data['Target'] = (nifty50_data['Tomorrow'] > nifty50_data['Close']).astype(int)

# %%
nifty50_data.index.min()
# Out:
# Timestamp('2000-01-04 00:00:00+0530', tz='Asia/Kolkata')

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=100,random_state=1)

train = nifty50_data.iloc[:-100]
test = nifty50_data.iloc[-100:]

predictors = ['Close', 'Volume', 'Open', 'High', 'Low']
model.fit(train[predictors], train['Target'])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
import pandas as pd
preds = pd.Series(preds, index=test.index)

# %%
print(nifty50_data.index.max())
print(nifty50_data.index.min())
# Out:
# 2023-12-29 00:00:00+05:30
# 2000-01-04 00:00:00+05:30

# %%
precision_score(test['Target'], preds)
# Out:
# 0.5774647887323944

# %%
combined = pd.concat([test['Target'], preds], axis=1)

combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
  model.fit(train[predictors], train['Target'])
  preds = model.predict(test[predictors])
  preds = pd.Series(preds, index=test.index, name='Predictions')
  combined = pd.concat([test['Target'], preds], axis=1)
  return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
  all_predictions = []
  for i in range(start, data.shape[0], step):
    train = data.iloc[0:i].copy()
    test = data.iloc[i:(i+step)].copy()
    predictions = predict(train, test, predictors, model)
    all_predictions.append(predictions)
  return pd.concat(all_predictions)

# %%
print(3321+2338)
print(nifty50_data.shape[0])
# Out:
# 5659
# 5771

# %%
predictions = backtest(nifty50_data, model, predictors)

# %%
predictions['Predictions'].value_counts()
# Out:
# 0    1989
# 1    1282
# Name: Predictions, dtype: int64

# %%
precision_score(predictions['Target'], predictions['Predictions'])
# Out:
# 0.516380655226209

# %%
predictions['Predictions'].value_counts() / predictions.shape[0]
# Out:
# 0    0.608071
# 1    0.391929
# Name: Predictions, dtype: float64

# %%
horizons = [2,5,60,250,1000]
new_predictors = []

for horizon in horizons:
  rolling_averages = nifty50_data.rolling(horizon).mean()

  ratio_column = f'Close_Ratio_{horizon}'
  nifty50_data[ratio_column] = nifty50_data['Close'] / rolling_averages['Close']

  trend_column = f'Trend_{horizon}'
  nifty50_data[trend_column] = nifty50_data.shift(1).rolling(horizon).sum()['Target']

  new_predictors += [ratio_column, trend_column]

# %%
nifty50_data
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2000-01-04 00:00:00+05:30    35.767719    35.767719    35.767719    35.767719
# 2000-01-05 00:00:00+05:30    36.180073    36.180073    36.180073    36.180073
# 2000-01-12 00:00:00+05:30    38.707344    38.707344    38.707344    38.707344
# 2000-02-07 00:00:00+05:30    46.176128    46.176128    46.176128    46.176128
# 2000-02-14 00:00:00+05:30    47.885376    47.885376    47.885376    47.885376
# ...                                ...          ...          ...          ...
# 2023-12-22 00:00:00+05:30  2562.199951  2580.550049  2548.000000  2564.699951
# 2023-12-26 00:00:00+05:30  2570.000000  2592.899902  2563.000000  2577.500000
# 2023-12-27 00:00:00+05:30  2578.500000  2599.350098  2572.250000  2586.350098
# 2023-12-28 00:00:00+05:30  2587.000000  2611.350098  2587.000000  2605.800049
# 2023-12-29 00:00:00+05:30  2608.050049  2614.800049  2579.149902  2584.850098
#
#                            Volume     Tomorrow  Target  Close_Ratio_2  \
# Date
# 2000-01-04 00:00:00+05:30    6400    36.180073       1            NaN
# 2000-01-05 00:00:00+05:30  418568    38.707344       1       1.005731
# 2000-01-12 00:00:00+05:30    4200    46.176128       1       1.033748
# 2000-02-07 00:00:00+05:30    8000    47.885376       1       1.087989
# 2000-02-14 00:00:00+05:30    2000    38.694046       0       1.018172
# ...                           ...          ...     ...            ...
# 2023-12-22 00:00:00+05:30  524558  2577.500000       1       1.000488
# 2023-12-26 00:00:00+05:30   90284  2586.350098       1       1.002489
# 2023-12-27 00:00:00+05:30  103806  2605.800049       1       1.001714
# 2023-12-28 00:00:00+05:30  183810  2584.850098       0       1.003746
# 2023-12-29 00:00:00+05:30  848448          NaN       0       0.995964
#
#                            Trend_2  Close_Ratio_5  Trend_5  Close_Ratio_60  \
# Date
# 2000-01-04 00:00:00+05:30      NaN            NaN      NaN             NaN
# 2000-01-05 00:00:00+05:30      NaN            NaN      NaN             NaN
# 2000-01-12 00:00:00+05:30      2.0            NaN      NaN             NaN
# 2000-02-07 00:00:00+05:30      2.0            NaN      NaN             NaN
# 2000-02-14 00:00:00+05:30      2.0       1.169553      NaN             NaN
# ...                            ...            ...      ...             ...
# 2023-12-22 00:00:00+05:30      2.0       1.007135      4.0        1.082094
# 2023-12-26 00:00:00+05:30      2.0       1.007607      4.0        1.085694
# 2023-12-27 00:00:00+05:30      2.0       1.008866      4.0        1.087762
# 2023-12-28 00:00:00+05:30      2.0       1.010270      5.0        1.093859
# 2023-12-29 00:00:00+05:30      1.0       1.000391      4.0        1.083258
#
#                            Trend_60  Close_Ratio_250  Trend_250  \
# Date
# 2000-01-04 00:00:00+05:30       NaN              NaN        NaN
# 2000-01-05 00:00:00+05:30       NaN              NaN        NaN
# 2000-01-12 00:00:00+05:30       NaN              NaN        NaN
# 2000-02-07 00:00:00+05:30       NaN              NaN        NaN
# 2000-02-14 00:00:00+05:30       NaN              NaN        NaN
# ...                             ...              ...        ...
# 2023-12-22 00:00:00+05:30      35.0         1.054333      128.0
# 2023-12-26 00:00:00+05:30      35.0         1.059811      128.0
# 2023-12-27 00:00:00+05:30      35.0         1.063689      128.0
# 2023-12-28 00:00:00+05:30      36.0         1.071878      129.0
# 2023-12-29 00:00:00+05:30      35.0         1.063484      129.0
#
#                            Close_Ratio_1000  Trend_1000
# Date
# 2000-01-04 00:00:00+05:30               NaN         NaN
# 2000-01-05 00:00:00+05:30               NaN         NaN
# 2000-01-12 00:00:00+05:30               NaN         NaN
# 2000-02-07 00:00:00+05:30               NaN         NaN
# 2000-02-14 00:00:00+05:30               NaN         NaN
# ...                                     ...         ...
# 2023-12-22 00:00:00+05:30          1.173402       524.0
# 2023-12-26 00:00:00+05:30          1.178650       525.0
# 2023-12-27 00:00:00+05:30          1.182110       525.0
# 2023-12-28 00:00:00+05:30          1.190418       525.0
# 2023-12-29 00:00:00+05:30          1.180277       525.0
#
# [5771 rows x 17 columns]

# %%
nifty50_data = nifty50_data.dropna()

# %%
nifty50_data
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2004-07-30 00:00:00+05:30    86.925341    89.527623    86.760988    89.281090
# 2004-08-02 00:00:00+05:30    89.847214    90.358537    88.614554    90.239838
# 2004-08-03 00:00:00+05:30    90.577680    91.225966    89.061968    89.381546
# 2004-08-04 00:00:00+05:30    89.299364    90.303754    88.313237    90.057220
# 2004-08-05 00:00:00+05:30    90.723768    92.202961    90.395061    91.846863
# ...                                ...          ...          ...          ...
# 2023-12-21 00:00:00+05:30  2510.449951  2572.500000  2510.449951  2562.199951
# 2023-12-22 00:00:00+05:30  2562.199951  2580.550049  2548.000000  2564.699951
# 2023-12-26 00:00:00+05:30  2570.000000  2592.899902  2563.000000  2577.500000
# 2023-12-27 00:00:00+05:30  2578.500000  2599.350098  2572.250000  2586.350098
# 2023-12-28 00:00:00+05:30  2587.000000  2611.350098  2587.000000  2605.800049
#
#                              Volume     Tomorrow  Target  Close_Ratio_2  \
# Date
# 2004-07-30 00:00:00+05:30  13001580    90.239838       1       1.015105
# 2004-08-02 00:00:00+05:30  11843128    89.381546       0       1.005341
# 2004-08-03 00:00:00+05:30  15653320    90.057220       1       0.995222
# 2004-08-04 00:00:00+05:30  12728400    91.846863       1       1.003765
# 2004-08-05 00:00:00+05:30  11155540    90.185051       0       1.009838
# ...                             ...          ...     ...            ...
# 2023-12-21 00:00:00+05:30    364795  2564.699951       1       1.006847
# 2023-12-22 00:00:00+05:30    524558  2577.500000       1       1.000488
# 2023-12-26 00:00:00+05:30     90284  2586.350098       1       1.002489
# 2023-12-27 00:00:00+05:30    103806  2605.800049       1       1.001714
# 2023-12-28 00:00:00+05:30    183810  2584.850098       0       1.003746
#
#                            Trend_2  Close_Ratio_5  Trend_5  Close_Ratio_60  \
# Date
# 2004-07-30 00:00:00+05:30      2.0       1.028700      4.0        1.103727
# 2004-08-02 00:00:00+05:30      2.0       1.032555      4.0        1.115617
# 2004-08-03 00:00:00+05:30      1.0       1.012369      4.0        1.104073
# 2004-08-04 00:00:00+05:30      1.0       1.010553      4.0        1.111600
# 2004-08-05 00:00:00+05:30      2.0       1.018695      4.0        1.133039
# ...                            ...            ...      ...             ...
# 2023-12-21 00:00:00+05:30      1.0       1.011676      4.0        1.082750
# 2023-12-22 00:00:00+05:30      2.0       1.007135      4.0        1.082094
# 2023-12-26 00:00:00+05:30      2.0       1.007607      4.0        1.085694
# 2023-12-27 00:00:00+05:30      2.0       1.008866      4.0        1.087762
# 2023-12-28 00:00:00+05:30      2.0       1.010270      5.0        1.093859
#
#                            Trend_60  Close_Ratio_250  Trend_250  \
# Date
# 2004-07-30 00:00:00+05:30      34.0         1.033172      136.0
# 2004-08-02 00:00:00+05:30      35.0         1.042949      137.0
# 2004-08-03 00:00:00+05:30      35.0         1.031727      137.0
# 2004-08-04 00:00:00+05:30      35.0         1.038227      137.0
# 2004-08-05 00:00:00+05:30      35.0         1.057426      138.0
# ...                             ...              ...        ...
# 2023-12-21 00:00:00+05:30      34.0         1.053074      128.0
# 2023-12-22 00:00:00+05:30      35.0         1.054333      128.0
# 2023-12-26 00:00:00+05:30      35.0         1.059811      128.0
# 2023-12-27 00:00:00+05:30      35.0         1.063689      128.0
# 2023-12-28 00:00:00+05:30      36.0         1.071878      129.0
#
#                            Close_Ratio_1000  Trend_1000
# Date
# 2004-07-30 00:00:00+05:30          1.613153       530.0
# 2004-08-02 00:00:00+05:30          1.628885       530.0
# 2004-08-03 00:00:00+05:30          1.611917       529.0
# 2004-08-04 00:00:00+05:30          1.622818       529.0
# 2004-08-05 00:00:00+05:30          1.653757       529.0
# ...                                     ...         ...
# 2023-12-21 00:00:00+05:30          1.172851       524.0
# 2023-12-22 00:00:00+05:30          1.173402       524.0
# 2023-12-26 00:00:00+05:30          1.178650       525.0
# 2023-12-27 00:00:00+05:30          1.182110       525.0
# 2023-12-28 00:00:00+05:30          1.190418       525.0
#
# [4770 rows x 17 columns]

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50,random_state=1)

# %%
def predict(train, test, predictors, model):
  model.fit(train[predictors], train['Target'])
  preds = model.predict_proba(test[predictors])[:,1]

  preds[preds >= 0.6] = 1
  preds[preds < 0.6] = 0

  preds = pd.Series(preds, index=test.index, name='Predictions')
  combined = pd.concat([test['Target'], preds], axis=1)
  return combined

# %%
predictions = backtest(nifty50_data, model, new_predictors)

# %%
predictions['Predictions'].value_counts()
# Out:
# 0.0    2043
# 1.0     227
# Name: Predictions, dtype: int64

# %%
precision_score(predictions['Target'], predictions['Predictions'])
# Out:
# 0.5506607929515418
