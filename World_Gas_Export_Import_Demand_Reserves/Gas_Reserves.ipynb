# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import matplotlib.animation as animation

from raceplotly.plots import barplot
import bar_chart_race as bcr

import seaborn as sns 

import warnings
import os
warnings.filterwarnings("ignore")

# %%
import pandas as pd
xls = pd.ExcelFile('T91_update2.xlsx')
data_1 = xls.parse('Table 9.1', skiprows=2, index_col=None)
data_1
# Out:
#          Unnamed: 0       1960          1961         1962          1963
# 0     OECD Americas       8304   8550.439701  8771.894663   8917.947879  \
# 1            Canada        660    721.615703   762.480083    762.480083
# 2             Chile       7396   7507.283998   7676.59458   7785.767796
# 3            Mexico         20         38.37        51.82          49.7
# 4     United States        228        283.17          281           320
# ..              ...        ...           ...          ...           ...
# 74      Total world      19168  20067.763034  20986.45133  22991.491212
# 75         of which        NaN           NaN          NaN           NaN
# 76             OPEC     7132.9       7273.45      7343.45       8105.41
# 77  OPEC percentage  37.212542     36.244448    34.991385     35.253955
# 78             OECD       8660   9096.739701  9694.634663  10500.187879
#
#             1964          1965          1966          1967          1968  ...
# ...

# %%
data_1.rename(columns ={'Unnamed: 0': 'Country'}, inplace = True)

# %%
data_1
# Out:
#             Country       1960          1961         1962          1963
# 0     OECD Americas       8304   8550.439701  8771.894663   8917.947879  \
# 1            Canada        660    721.615703   762.480083    762.480083
# 2             Chile       7396   7507.283998   7676.59458   7785.767796
# 3            Mexico         20         38.37        51.82          49.7
# 4     United States        228        283.17          281           320
# ..              ...        ...           ...          ...           ...
# 74      Total world      19168  20067.763034  20986.45133  22991.491212
# 75         of which        NaN           NaN          NaN           NaN
# 76             OPEC     7132.9       7273.45      7343.45       8105.41
# 77  OPEC percentage  37.212542     36.244448    34.991385     35.253955
# 78             OECD       8660   9096.739701  9694.634663  10500.187879
#
#             1964          1965          1966          1967          1968  ...
# ...

# %%
drop_row75 = data_1[data_1.Country =='of which'].index
data_1.drop(drop_row75, inplace=True)
data_1
# Out:
#             Country       1960          1961         1962          1963
# 0     OECD Americas       8304   8550.439701  8771.894663   8917.947879  \
# 1            Canada        660    721.615703   762.480083    762.480083
# 2             Chile       7396   7507.283998   7676.59458   7785.767796
# 3            Mexico         20         38.37        51.82          49.7
# 4     United States        228        283.17          281           320
# ..              ...        ...           ...          ...           ...
# 73           Others          2             2            2             2
# 74      Total world      19168  20067.763034  20986.45133  22991.491212
# 76             OPEC     7132.9       7273.45      7343.45       8105.41
# 77  OPEC percentage  37.212542     36.244448    34.991385     35.253955
# 78             OECD       8660   9096.739701  9694.634663  10500.187879
#
#             1964          1965          1966          1967          1968  ...
# ...

# %%
drop_opec_per = data_1[data_1.Country =='OPEC percentage'].index
data_1.drop(drop_opec_per, inplace=True)
data_1
# Out:
#           Country    1960          1961         1962          1963
# 0   OECD Americas    8304   8550.439701  8771.894663   8917.947879  \
# 1          Canada     660    721.615703   762.480083    762.480083
# 2           Chile    7396   7507.283998   7676.59458   7785.767796
# 3          Mexico      20         38.37        51.82          49.7
# 4   United States     228        283.17          281           320
# ..            ...     ...           ...          ...           ...
# 72        Romania     493        498.92          563           598
# 73         Others       2             2            2             2
# 74    Total world   19168  20067.763034  20986.45133  22991.491212
# 76           OPEC  7132.9       7273.45      7343.45       8105.41
# 78           OECD    8660   9096.739701  9694.634663  10500.187879
#
#             1964          1965          1966          1967          1968  ...
# 0     9144.71705   9330.215652   9496.620885   9641.882818   9618.012745  ...  \
# ...

# %%
drop_others = data_1[data_1.Country =='Others'].index
data_1.drop(drop_others, inplace=True)
data_1
# Out:
#           Country    1960          1961         1962          1963
# 0   OECD Americas    8304   8550.439701  8771.894663   8917.947879  \
# 1          Canada     660    721.615703   762.480083    762.480083
# 2           Chile    7396   7507.283998   7676.59458   7785.767796
# 3          Mexico      20         38.37        51.82          49.7
# 4   United States     228        283.17          281           320
# ..            ...     ...           ...          ...           ...
# 71       Bulgaria       0             0            0             0
# 72        Romania     493        498.92          563           598
# 74    Total world   19168  20067.763034  20986.45133  22991.491212
# 76           OPEC  7132.9       7273.45      7343.45       8105.41
# 78           OECD    8660   9096.739701  9694.634663  10500.187879
#
#             1964          1965          1966          1967          1968  ...
# 0     9144.71705   9330.215652   9496.620885   9641.882818   9618.012745  ...  \
# ...

# %%
[data_1.Country]
# Out:
# [0     OECD Americas
#  1            Canada
#  2             Chile
#  3            Mexico
#  4     United States
#            ...
#  71         Bulgaria
#  72          Romania
#  74      Total world
#  76             OPEC
#  78             OECD
#  Name: Country, Length: 69, dtype: object]

# %%
drop_rows = ['OECD Americas','OECD Europe','OECD Asia Pacific','Other Asia', 'Latin America','Middle East',
            'Africa', 'Other Eurasia', 'Other Europe', 'Total world', 'OPEC', 'OECD']

data_filtered = data_1[~data_1['Country'].isin(drop_rows)]

data_filtered = data_filtered.reset_index()

data_filtered = data_filtered.drop('index', axis=1)

data_filtered.Country
# Out:
# 0                   Canada
# 1                    Chile
# 2                   Mexico
# 3            United States
# 4                  Denmark
# 5                  Germany
# 6                    Italy
# 7              Netherlands
# 8                   Norway
# 9                   Poland
# 10          United Kingdom
# 11               Australia
# 12                   Japan
# 13             New Zealand
# 14                   China
# 15                   India
# 16              Bangladesh
# 17                  Brunei
# 18               Indonesia
# 19                Malaysia
# 20                 Myanmar
# 21                Pakistan
# 22                Thailand
# 23                 Vietnam
# 24               Argentina
# 25                 Bolivia
# 26                  Brazil
# 27                Colombia
# 28                 Ecuador
# 29                    Peru
# 30       Trinidad & Tobago
# 31               Venezuela
# 32                 IR Iran
# 33                    Iraq
# ...

# %%
drop_str_na = data_filtered[data_filtered[1960] == 'na'].index

data_filtered.drop(drop_str_na, inplace=True)

# %%
data_filtered.reset_index(inplace = True)

# %%
data_filtered = data_filtered.drop('index', axis=1)

# %%
columns_to_convert = [1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
       1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983,
       1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995,
       1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
       2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
       2020, 2021, 2022]

data_filtered[columns_to_convert] = data_filtered[columns_to_convert].astype(float)

# %%
data_filtered.columns
# Out:
# Index(['Country',      1960,      1961,      1962,      1963,      1964,
#             1965,      1966,      1967,      1968,      1969,      1970,
#             1971,      1972,      1973,      1974,      1975,      1976,
#             1977,      1978,      1979,      1980,      1981,      1982,
#             1983,      1984,      1985,      1986,      1987,      1988,
#             1989,      1990,      1991,      1992,      1993,      1994,
#             1995,      1996,      1997,      1998,      1999,      2000,
#             2001,      2002,      2003,      2004,      2005,      2006,
#             2007,      2008,      2009,      2010,      2011,      2012,
#             2013,      2014,      2015,      2016,      2017,      2018,
#             2019,      2020,      2021,      2022],
#       dtype='object')

# %%
data_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 64 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  52 non-null     object
#  1   1960     52 non-null     float64
#  2   1961     52 non-null     float64
#  3   1962     52 non-null     float64
#  4   1963     52 non-null     float64
#  5   1964     52 non-null     float64
#  6   1965     52 non-null     float64
#  7   1966     52 non-null     float64
#  8   1967     52 non-null     float64
#  9   1968     52 non-null     float64
#  10  1969     52 non-null     float64
#  11  1970     52 non-null     float64
#  12  1971     52 non-null     float64
#  13  1972     52 non-null     float64
#  14  1973     52 non-null     float64
#  15  1974     52 non-null     float64
#  16  1975     52 non-null     float64
#  17  1976     52 non-null     float64
#  18  1977     52 non-null     float64
#  19  1978     52 non-null     float64
# ...

# %%
data_filtered.columns
# Out:
# Index(['Country',      1960,      1961,      1962,      1963,      1964,
#             1965,      1966,      1967,      1968,      1969,      1970,
#             1971,      1972,      1973,      1974,      1975,      1976,
#             1977,      1978,      1979,      1980,      1981,      1982,
#             1983,      1984,      1985,      1986,      1987,      1988,
#             1989,      1990,      1991,      1992,      1993,      1994,
#             1995,      1996,      1997,      1998,      1999,      2000,
#             2001,      2002,      2003,      2004,      2005,      2006,
#             2007,      2008,      2009,      2010,      2011,      2012,
#             2013,      2014,      2015,      2016,      2017,      2018,
#             2019,      2020,      2021,      2022],
#       dtype='object')

# %%
data_filtered
# Out:
#                  Country         1960         1961         1962         1963
# 0                 Canada   660.000000   721.615703   762.480083   762.480083  \
# 1                  Chile  7396.000000  7507.283998  7676.594580  7785.767796
# 2                 Mexico    20.000000    38.370000    51.820000    49.700000
# 3          United States   228.000000   283.170000   281.000000   320.000000
# 4                Denmark     0.000000     0.000000     0.000000     0.000000
# 5                Germany    20.000000    25.000000    26.000000    59.000000
# 6                  Italy    90.000000   115.000000   123.000000   133.000000
# 7            Netherlands    10.000000   164.000000   500.000000  1100.000000
# 8                 Norway     0.000000     0.000000     0.000000     0.000000
# 9                 Poland    10.000000    14.160000    13.400000    12.500000
# 10        United Kingdom     0.000000     0.140000     0.140000     0.140000
# ...

# %%
data_filtered.columns
# Out:
# Index(['Country',      1960,      1961,      1962,      1963,      1964,
#             1965,      1966,      1967,      1968,      1969,      1970,
#             1971,      1972,      1973,      1974,      1975,      1976,
#             1977,      1978,      1979,      1980,      1981,      1982,
#             1983,      1984,      1985,      1986,      1987,      1988,
#             1989,      1990,      1991,      1992,      1993,      1994,
#             1995,      1996,      1997,      1998,      1999,      2000,
#             2001,      2002,      2003,      2004,      2005,      2006,
#             2007,      2008,      2009,      2010,      2011,      2012,
#             2013,      2014,      2015,      2016,      2017,      2018,
#             2019,      2020,      2021,      2022],
#       dtype='object')

# %%
data_2 = data_filtered.copy()
data_2
# Out:
#                  Country         1960         1961         1962         1963
# 0                 Canada   660.000000   721.615703   762.480083   762.480083  \
# 1                  Chile  7396.000000  7507.283998  7676.594580  7785.767796
# 2                 Mexico    20.000000    38.370000    51.820000    49.700000
# 3          United States   228.000000   283.170000   281.000000   320.000000
# 4                Denmark     0.000000     0.000000     0.000000     0.000000
# 5                Germany    20.000000    25.000000    26.000000    59.000000
# 6                  Italy    90.000000   115.000000   123.000000   133.000000
# 7            Netherlands    10.000000   164.000000   500.000000  1100.000000
# 8                 Norway     0.000000     0.000000     0.000000     0.000000
# 9                 Poland    10.000000    14.160000    13.400000    12.500000
# 10        United Kingdom     0.000000     0.140000     0.140000     0.140000
# ...

# %%
data_2 = data_2.set_index('Country')

# %%
data_2
# Out:
#                              1960         1961         1962         1963
# Country
# Canada                 660.000000   721.615703   762.480083   762.480083  \
# Chile                 7396.000000  7507.283998  7676.594580  7785.767796
# Mexico                  20.000000    38.370000    51.820000    49.700000
# United States          228.000000   283.170000   281.000000   320.000000
# Denmark                  0.000000     0.000000     0.000000     0.000000
# Germany                 20.000000    25.000000    26.000000    59.000000
# Italy                   90.000000   115.000000   123.000000   133.000000
# Netherlands             10.000000   164.000000   500.000000  1100.000000
# Norway                   0.000000     0.000000     0.000000     0.000000
# Poland                  10.000000    14.160000    13.400000    12.500000
# United Kingdom           0.000000     0.140000     0.140000     0.140000
# Australia                0.000000     0.000000     0.200000     0.600000
# ...

# %%
data_2.columns.name = 'Year'
data_2.index.name = 'Country'

# %%
data_3 = data_2.T
data_3
# Out:
# Country       Canada        Chile      Mexico  United States  Denmark
# Year
# 1960      660.000000  7396.000000   20.000000        228.000    0.000  \
# 1961      721.615703  7507.283998   38.370000        283.170    0.000
# 1962      762.480083  7676.594580   51.820000        281.000    0.000
# 1963      762.480083  7785.767796   49.700000        320.000    0.000
# 1964      846.017269  7929.569780   43.200000        325.930    0.000
# ...              ...          ...         ...            ...      ...
# 2018     2094.000000     4.000000  273.370812      13437.000   69.000
# 2019     2471.000000     8.000000  262.950213      13171.000   66.000
# 2020     2471.000000     8.000000  282.630420      13171.000   64.000
# 2021     2471.000000    10.000000  305.283895      12602.000   63.000
# 2022     2463.616000    10.000000  312.071495      16395.956   62.006
#
# Country  Germany    Italy  Netherlands     Norway  Poland  ...    Congo
# ...

# %%
data_3.sort_values(list(data_3.columns),inplace=True)
data_4 = data_3.sort_index()

# %%
data_4
# Out:
# Country       Canada        Chile      Mexico  United States  Denmark
# Year
# 1960      660.000000  7396.000000   20.000000        228.000    0.000  \
# 1961      721.615703  7507.283998   38.370000        283.170    0.000
# 1962      762.480083  7676.594580   51.820000        281.000    0.000
# 1963      762.480083  7785.767796   49.700000        320.000    0.000
# 1964      846.017269  7929.569780   43.200000        325.930    0.000
# ...              ...          ...         ...            ...      ...
# 2018     2094.000000     4.000000  273.370812      13437.000   69.000
# 2019     2471.000000     8.000000  262.950213      13171.000   66.000
# 2020     2471.000000     8.000000  282.630420      13171.000   64.000
# 2021     2471.000000    10.000000  305.283895      12602.000   63.000
# 2022     2463.616000    10.000000  312.071495      16395.956   62.006
#
# Country  Germany    Italy  Netherlands     Norway  Poland  ...    Congo
# ...

# %%
plt.rcParams['animation.ffmpeg_path'] = "D:/SVJ/ffmpeg_2023/bin/ffmpeg.exe"
FFwriter = animation.FFMpegWriter()

# %%
bcr.bar_chart_race(df=data_4,
                   filename= None,
                   orientation='h',
                   sort='desc',
                   n_bars=10,
                   fixed_order=False,
                   fixed_max=True,
                   steps_per_period=10,
                   interpolate_period=False,
                   label_bars=True,
                   bar_size=.90,
                   period_label={'x': .99, 'y': .25, 'ha': 'right', 'va': 'center'},
                   period_summary_func=lambda v, r: {'x': .99, 'y': .18,
                                                      's': f'Year',
                                                      'ha': 'right', 'size': 8, 'family': 'Courier New'},
                   period_length=1000,
                   figsize=(6.5,5),
                   dpi=144,
                   cmap='antique',
                   title=f'World proven natural gas reserves by country (bn standard cu m)',
                   title_size='',
                   bar_label_size=7,
                   tick_label_size=5,
                   shared_fontdict={'family' : 'Tahoma','color' : '.1'},
                   scale='linear',
                   writer=None,
                   fig=None,
                   bar_kwargs={'alpha': .7},
                   filter_column_colors=True)
# Out:
# <video width="1022" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
data_4.columns
# Out:
# Index(['Canada', 'Chile', 'Mexico', 'United States', 'Denmark', 'Germany',
#        'Italy', 'Netherlands', 'Norway', 'Poland', 'United Kingdom',
#        'Australia', 'Japan', 'New Zealand', 'China', 'India', 'Bangladesh',
#        'Brunei', 'Indonesia', 'Malaysia', 'Myanmar', 'Pakistan', 'Thailand',
#        'Vietnam', 'Argentina', 'Bolivia', 'Brazil', 'Colombia', 'Ecuador',
#        'Peru', 'Trinidad & Tobago', 'Venezuela', 'IR Iran', 'Iraq', 'Kuwait',
#        'Oman', 'Qatar', 'Saudi Arabia', 'United Arab Emirates', 'Algeria',
#        'Angola', 'Cameroon', 'Congo', 'Egypt', 'Equatorial Guinea', 'Gabon',
#        'Libya', 'Mozambique', 'Nigeria', 'Russia', 'Bulgaria', 'Romania'],
#       dtype='object', name='Country')

# %%
from plotly.offline import iplot, init_notebook_mode
import math
import bokeh 
import matplotlib.pyplot as plt
import plotly.express as px
from urllib.request import urlopen
import json
from dateutil import parser
from bokeh.layouts import gridplot
from bokeh.plotting import figure, show, output_file
from bokeh.layouts import row, column
from bokeh.resources import INLINE
from bokeh.io import output_notebook
from bokeh.models import Span

# %%
data_4.columns
# Out:
# Index(['Canada', 'Chile', 'Mexico', 'United States', 'Denmark', 'Germany',
#        'Italy', 'Netherlands', 'Norway', 'Poland', 'United Kingdom',
#        'Australia', 'Japan', 'New Zealand', 'China', 'India', 'Bangladesh',
#        'Brunei', 'Indonesia', 'Malaysia', 'Myanmar', 'Pakistan', 'Thailand',
#        'Vietnam', 'Argentina', 'Bolivia', 'Brazil', 'Colombia', 'Ecuador',
#        'Peru', 'Trinidad & Tobago', 'Venezuela', 'IR Iran', 'Iraq', 'Kuwait',
#        'Oman', 'Qatar', 'Saudi Arabia', 'United Arab Emirates', 'Algeria',
#        'Angola', 'Cameroon', 'Congo', 'Egypt', 'Equatorial Guinea', 'Gabon',
#        'Libya', 'Mozambique', 'Nigeria', 'Russia', 'Bulgaria', 'Romania'],
#       dtype='object', name='Country')

# %%
data_filter_copy = data_filtered.copy()
data_filter_copy
# Out:
#                  Country         1960         1961         1962         1963
# 0                 Canada   660.000000   721.615703   762.480083   762.480083  \
# 1                  Chile  7396.000000  7507.283998  7676.594580  7785.767796
# 2                 Mexico    20.000000    38.370000    51.820000    49.700000
# 3          United States   228.000000   283.170000   281.000000   320.000000
# 4                Denmark     0.000000     0.000000     0.000000     0.000000
# 5                Germany    20.000000    25.000000    26.000000    59.000000
# 6                  Italy    90.000000   115.000000   123.000000   133.000000
# 7            Netherlands    10.000000   164.000000   500.000000  1100.000000
# 8                 Norway     0.000000     0.000000     0.000000     0.000000
# 9                 Poland    10.000000    14.160000    13.400000    12.500000
# 10        United Kingdom     0.000000     0.140000     0.140000     0.140000
# ...

# %%
# Reshape the DataFrame using pd.melt
df_melted = pd.melt(data_filter_copy, id_vars=['Country'], var_name='year', value_name='value')

df_melted
# Out:
#             Country  year        value
# 0            Canada  1960    660.00000
# 1             Chile  1960   7396.00000
# 2            Mexico  1960     20.00000
# 3     United States  1960    228.00000
# 4           Denmark  1960      0.00000
# ...             ...   ...          ...
# 3271     Mozambique  2022   2840.00000
# 3272        Nigeria  2022   5913.40704
# 3273         Russia  2022  47759.00000
# 3274       Bulgaria  2022      4.00000
# 3275        Romania  2022     74.00000
#
# [3276 rows x 3 columns]

# %%
choro_map=px.choropleth(df_melted,
                        locations="Country", 
                        locationmode = "country names",
                        color="value", 
                        hover_name="Country", 
                        animation_frame="year",
                        scope='world'
                       )

choro_map.update_layout(
    title_text = 'World proven natural gas reserves by country (bn standard cu m)',
    title_x = 0.5,
    geo=dict(
        showframe = False,
        showcoastlines = False,
    ))
    
choro_map.show()
# Out:
# <div>                            <div id="a1f1ba7b-b80d-4c93-9691-e93b729ce5f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1f1ba7b-b80d-4c93-9691-e93b729ce5f6")) {                    Plotly.newPlot(                        "a1f1ba7b-b80d-4c93-9691-e93b729ce5f6",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eyear=1960\u003cbr\u003eCountry=%{location}\u003cbr\u003evalue=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Canada","Chile","Mexico","United States","Denmark","Germany","Italy","Netherlands","Norway","Poland","United Kingdom","Australia","Japan","New Zealand","China","India","Bangladesh","Brunei","Indonesia","Malaysia","Myanm
# ...

# %%
df_melted
# Out:
#             Country  year        value
# 0            Canada  1960    660.00000
# 1             Chile  1960   7396.00000
# 2            Mexico  1960     20.00000
# 3     United States  1960    228.00000
# 4           Denmark  1960      0.00000
# ...             ...   ...          ...
# 3271     Mozambique  2022   2840.00000
# 3272        Nigeria  2022   5913.40704
# 3273         Russia  2022  47759.00000
# 3274       Bulgaria  2022      4.00000
# 3275        Romania  2022     74.00000
#
# [3276 rows x 3 columns]

# %%
# !pip install psutil
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
